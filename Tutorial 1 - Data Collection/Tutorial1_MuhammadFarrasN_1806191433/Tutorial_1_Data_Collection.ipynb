# %% [markdown]
# # Tutorial 1 - Data Collection

# %% [markdown]
# Nama:
# <br>
# NPM:

# %% [markdown]
# Pada tutorial ini, kita akan melakukan:
# 1. Pengumpulan data dari Twitter menggunakan Tweepy (dengan Twitter Search API), Twint, dan Twecoll. Terdapat dua jenis data yang akan kita kumpulkan, yaitu data tekstual tweet dan data network.
# 2. Pengumpulan data dari suatu (<i>Web scraping</i>).
# 3. Pengumpulan data dari Linkedin.
#
# Sebelum memulai tutorial, kita akan menginstal <i>library</i> yang kita perlukan:

# %%
# !pip install tweepy
# !pip install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# !pip install selenium
# !pip install bs4
# !pip install requests
# !pip install linkedin_scraper
# Out:
# Collecting tweepy
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\asus\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\asus\appdata\roaming\python\python37\site-packages (from tweepy) (1.12.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\asus\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.10.0
# Collecting twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to c:\users\asus\appdata\local\temp\pip-install-ynb7h7nx\twint_92671e4004414347827f12ccd6be39a1
# Collecting aiohttp
#   Downloading aiohttp-3.7.4-cp37-cp37m-win_amd64.whl (630 kB)
# Collecting aiodns
#   Downloading aiodns-2.0.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\lib\site-packages (from twint) (4.8.0)
# Collecting cchardet
#   Downloading cchardet-2.1.7-cp37-cp37m-win_amd64.whl (114 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting elasticsearch
#   Downloading elasticsearch-7.11.0-py2.py3-none-any.whl (325 kB)
# Requirement already satisfied: pysocks in c:\users\asus\anaconda3\lib\site-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (from twint) (0.25.1)
# Collecting aiohttp_socks
#   Downloading aiohttp_socks-0.6.0-py3-none-any.whl (9.2 kB)
# Collecting schedule
#   Downloading schedule-1.0.0-py2.py3-none-any.whl (9.0 kB)
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting googletransx
#   Downloading googletransx-2.4.2.tar.gz (13 kB)
# Collecting pycares>=3.0.0
#   Downloading pycares-3.1.1-cp37-cp37m-win_amd64.whl (70 kB)
# Requirement already satisfied: cffi>=1.5.0 in c:\users\asus\anaconda3\lib\site-packages (from pycares>=3.0.0->aiodns->twint) (1.12.3)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.5.0->pycares>=3.0.0->aiodns->twint) (2.19)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-win_amd64.whl (48 kB)
# Collecting typing-extensions>=3.6.5
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-win_amd64.whl (124 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp->twint) (19.2.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp->twint) (3.0.4)
# Requirement already satisfied: idna>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.8)
# Collecting python-socks[asyncio]>=1.2.2
#   Downloading python_socks-1.2.2-py3-none-any.whl (35 kB)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4->twint) (1.9.3)
# Requirement already satisfied: urllib3<2,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from elasticsearch->twint) (1.24.2)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from elasticsearch->twint) (2019.9.11)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from googletransx->twint) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas->twint) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas->twint) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\asus\anaconda3\lib\site-packages (from pandas->twint) (1.16.5)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.6.1->pandas->twint) (1.12.0)
# Building wheels for collected packages: twint, fake-useragent, googletransx
#   Building wheel for twint (setup.py): started
#   Building wheel for twint (setup.py): finished with status 'done'
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=39137 sha256=d865a1700f91fd045c87b27dd964b22cc89293a8c48f6e18727f3152d7f7fd2e
#   Stored in directory: C:\Users\ASUS\AppData\Local\Temp\pip-ephem-wheel-cache-qmh340k8\wheels\8d\dc\9f\74b4483d5f997036f04aec7f42bd4b3c80f04264920c368068
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13489 sha256=92b58c006ff79630c1458c4d2d320e0ade80f2248acec3b2730e0c7ee6ca8a9a
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\ed\f7\62\50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for googletransx (setup.py): started
#   Building wheel for googletransx (setup.py): finished with status 'done'
#   Created wheel for googletransx: filename=googletransx-2.4.2-py3-none-any.whl size=15974 sha256=afc1b39bc7049c9e638ae01d848c44fa862ddc2875987439eb03d7783f404dda
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\66\d5\b1\31104b338f7fd45aa8f7d22587765db06773b13df48a89735f
# Successfully built twint fake-useragent googletransx
# Installing collected packages: typing-extensions, multidict, yarl, python-socks, async-timeout, pycares, geographiclib, aiohttp, schedule, googletransx, geopy, fake-useragent, elasticsearch, dataclasses, cchardet, aiohttp-socks, aiodns, twint
# Successfully installed aiodns-2.0.0 aiohttp-3.7.4 aiohttp-socks-0.6.0 async-timeout-3.0.1 cchardet-2.1.7 dataclasses-0.6 elasticsearch-7.11.0 fake-useragent-0.1.11 geographiclib-1.50 geopy-2.1.0 googletransx-2.4.2 multidict-5.1.0 pycares-3.1.1 python-socks-1.2.2 schedule-1.0.0 twint-2.1.21 typing-extensions-3.7.4.3 yarl-1.6.3
#   Running command git clone -q https://github.com/twintproject/twint.git 'C:\Users\ASUS\AppData\Local\Temp\pip-install-ynb7h7nx\twint_92671e4004414347827f12ccd6be39a1'
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   WARNING: The script twint.exe is installed in 'C:\Users\ASUS\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\asus\anaconda3\lib\site-packages (from selenium) (1.24.2)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\lib\site-packages (from bs4) (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (1.9.3)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1278 sha256=fdba9d1813bc1e96344cb307df779a34ee0da96114528c041642b84fea20e74a
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\0a\9e\ba\20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests) (2.8)
# Collecting linkedin_scraper
#   Downloading linkedin_scraper-2.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: lxml in c:\users\asus\anaconda3\lib\site-packages (from linkedin_scraper) (4.4.1)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from linkedin_scraper) (2.22.0)
# Requirement already satisfied: selenium in c:\users\asus\anaconda3\lib\site-packages (from linkedin_scraper) (3.141.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests->linkedin_scraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->linkedin_scraper) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->linkedin_scraper) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->linkedin_scraper) (2.8)
# Installing collected packages: linkedin-scraper
# Successfully installed linkedin-scraper-2.7.2

# %% [markdown]
# # Data Collection - Twitter (Tweepy)

# %% [markdown]
# ## Twitter Search API
#
# Pengumpulan data tekstual <i>tweet</i> dapat dilakukan dengan menggunakan Twitter API. Terdapat dua kategori API Twitter, yaitu <i>Twitter Search API</i> dan <i>Twitter Streaming API</i>. Perbedaan mendasar dari kedua jenis API tersebut adalah pada waktu data <i>tweet</i> yang akan dikumpulkan. <i>Twitter Search API</i> mengambil data <i>past tweet</i>, yaitu data <i>tweet</i> dengan kriteria tertentu yang diposting pada rentang waktu H-7 hari sampai dengan waktu <i>crawling</i>. Sementara itu, <i>Twitter Streaming API</i> akan mengambil data secara <i>real-time</i> pada saat program <i>crawling</i> dijalankan. Untuk memanggil kedua API tersebut, akan digunakan <i>library</i> Tweepy.
#
# Langkah-langkah untuk melakukan proses <i>search tweet data</i> adalah sebagai berikut:

# %% [markdown]
# ### Import library
#
# <b>Code 1</b>:

# %%
import tweepy

# %% [markdown]
# ### Access token variables
#
# Pertama-tama, kita harus mendaftarkan akun Twitter kita agar dapat menggunakan API. Setelah itu, Twitter akan memberikan `consumer_key`, `consumer_secret`, `access_token`, dan `access_token_secret`. Token tersebut wajib dimasukkan ke dalam parameter penggunaan Tweepy.
#
# <b>Code 2</b>:

# %%
consumer_key = "IaGI9Y9bc33VARK5K4OqgCmNF" # masukkan consumer_key Anda
consumer_secret = "IlzLWseGtVxb2ghlBYY125Fq2yPISiAPui3g31kHRbPSRWKJ17" # masukkan consumer_secret Anda
access_token = "947706038-co0h4yFWIylo67AQzqfP1RyJTURaa4CWXmDrhNF3" # masukkan access_token Anda
access_token_secret = "zhI2DKCJU8rai4gaXQTQItcVmmrC8UnuhN95sLAXtzaX4" # masukkan access_token_secret Anda

# %% [markdown]
# ### Setting authentication dan connection
#
# Pada tahap ini, kita membuat <i>extractor</i> yang berisi pengaturan autentifikasi dan koneksi berdasarkan <i>key</i> dan <i>token</i> yang sudah diberikan.
#
# <b>Code 3</b>:

# %%
def twitter_setup():
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    return api
 
extractor = twitter_setup()

# %% [markdown]
# ### Crawling tweet berdasarkan query
#
# Pada contoh <b>Code 4</b> di bawah ini, <i>tweet</i> yang ingin dicari adalah 10 <i>tweet</i> yang mengandung kata `pemilu` dan berbahasa Indonesia. Parameter `extended` menunjukkan bahwa kita ingin mengambil seluruh teks pada <i>tweet</i> dan tidak hanya terbatas pada 140 karakter saja. Parameter `result_type='recent'` menunjukkan bahwa <i>tweet</i> yang kita ambil merupakan <i>tweet</i> terbaru. Terdapat jenis `result_type` yang lain, misalnya `popular` dan `mixed` (menggabungkan <i>tweet</i> terbaru dan populer).
#
# <b>Code 4</b>:

# %%
tweets = extractor.search(
    q="pemilu", lang="id", result_type="recent", count=10, tweet_mode="extended")

print("Jumlah tweet yang berhasil didapatkan: {}.\n".format(len(tweets)))
# Out:
# Jumlah tweet yang berhasil didapatkan: 10.

# %%
# contoh data
tweets[9]._json
# Out:
# {'created_at': 'Sun Mar 07 15:45:05 +0000 2021',
#  'id': 1368588520407715842,
#  'id_str': '1368588520407715842',
#  'full_text': 'Kesediaan Pak Moeldoko menjadi Ketum Demokrat KLB Sumut, tentu sdh pertimbangkan baik buruknya utk Demokrat dan utk negara menuju Pilpres dan Pilkada 2024. Dlm konteks Pemilu, apa yg terjadi dlm Pilkada DKI 2017 dan Pilpres 2019 tdk boleh terulang dlm Pemilu 2024."',
#  'truncated': False,
#  'display_text_range': [0, 265],
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1152165722958680064,
#   'id_str': '1152165722958680064',
#   'name': 'Aris Here Wila',
#   'screen_name': 'ArisWila',
#   'location': '',
#   'description': "Merah darah-ku dan Putih tulang-ku 👉❤🇮🇩❤👈 Berani karena benar' takut karena salah.",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2056,
#   'friends_count': 2605,
#   'listed_count': 0,
#   'created_at': 'Fri Jul 19 10:38:09 +0000 2019',
#   'favourites_count': 17254,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 12762,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1342874678897963008/FOXNWPOq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1342874678897963008/FOXNWPOq_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 11,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'in'}

# %% [markdown]
# ### <i>Crawling tweet</i> dari <i>username</i> spesifik
#
# Untuk mendapatkan <i>tweet</i> dari <i>username</i> spesifk, digunakan fungsi `user_timeline` dengan parameter `screen_name`. Pada contoh ini akan diambil 10 <i>tweet</i> terkini dari @Univ_Indonesia.
#
# <b>Code 5</b>:

# %%
tweets2 = extractor.user_timeline(
    screen_name="@univ_indonesia", lang="id", result_type="recent", count=10, tweet_mode="extended")

print("Jumlah tweet dari @Univ_Indonesia yang berhasil didapatkan: {}.\n".format(len(tweets2)))
# Out:
# Jumlah tweet dari @Univ_Indonesia yang berhasil didapatkan: 10.

# %%
# contoh data
tweets2[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x000001A36E19B388>, _json={'created_at': 'Wed Mar 03 03:37:02 +0000 2021', 'id': 1366955749935632389, 'id_str': '1366955749935632389', 'full_text': '@cwinderellaa konsekuensinya adalah Indeks Prestasi Sekolah akan menurun yang berdampak pada penerimaan mahasiswa baru tahun mendatang.', 'truncated': False, 'display_text_range': [14, 135], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'cwinderellaa', 'name': 'caca', 'id': 1095846022541000705, 'id_str': '1095846022541000705', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': 1366953364815192067, 'in_reply_to_status_id_str': '1366953364815192067', 'in_reply_to_user_id': 1095846022541000705, 'in_reply_to_user_id_str': '1095846022541000705', 'in_reply_to_screen_name': 'cwinderellaa', 'user': {'id': 74646907, 'id_str': '74646907', 'name': 'UniversitasIndonesia', 'screen_name': 'univ_indonesia', 'location': '', 'description': 'Official account of Universitas Indonesia. Delivering news, events, and stories on campus or something you should know. Add us on LINE @univ_indonesia', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1239195, 'friends_count': 94, 'listed_count': 571, 'created_at': 'Wed Sep 16 03:57:13 +0000 2009', 'favourites_count': 673, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 35216, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1364419729096511488/_DzbKx15_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364419729096511488/_DzbKx15_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74646907/1614137989', 'profile_link_color': 'FFCC4D', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFD608', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'in'}, created_at=datetime.datetime(2021, 3, 3, 3, 37, 2), id=1366955749935632389, id_str='1366955749935632389', full_text='@cwinderellaa konsekuensinya adalah Indeks Prestasi Sekolah akan menurun yang berdampak pada penerimaan mahasiswa baru tahun mendatang.', truncated=False, display_text_range=[14, 135], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'cwinderellaa', 'name': 'caca', 'id': 1095846022541000705, 'id_str': '1095846022541000705', 'indices': [0, 13]}], 'urls': []}, source='Hootsuite Inc.', source_url='https://www.hootsuite.com', in_reply_to_status_id=1366953364815192067, in_reply_to_status_id_str='1366953364815192067', in_reply_to_user_id=1095846022541000705, in_reply_to_user_id_str='1095846022541000705', in_reply_to_screen_name='cwinderellaa', author=User(_api=<tweepy.api.API object at 0x000001A36E19B388>, _json={'id': 74646907, 'id_str': '74646907', 'name': 'UniversitasIndonesia', 'screen_name': 'univ_indonesia', 'location': '', 'description': 'Official account of Universitas Indonesia. Delivering news, events, and stories on campus or something you should know. Add us on LINE @univ_indonesia', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1239195, 'friends_count': 9 ...

# %% [markdown]
# ### Menyimpan hasil <i>crawl tweet</i> ke CSV
#
# Langkah selanjutnya adalah menyimpan <i>tweet</i> yang diambil ke dalam <i>file</i> csv. Pada percobaan ini, akan disimpan <i>tweet</i> hasil dari pencarian pada <b>Code 4</b>.
#
# <b>Code 6</b>:

# %%
fw = open("hasil_tweet_c5.csv", "w", encoding ="utf-8")
for tweet in tweets:
    # mendapatkan tweet > 140 chars
    text = tweet.full_text
    
    # mendapatkan bio author
    bio = tweet.user.description

    # mendapatkan tweet asli yang diretweet
    if hasattr(tweet, "retweeted_status"):
        text = tweet.retweeted_status.full_text
        
    text = text.replace("\n", " ")

    # menuliskan ke dalam file .csv
    fw.write(text+ " "+ ", Bio author : " + bio +"\n")

fw.close()

# %% [markdown]
# Selain parameter-parameter diatas, terdapat pula parameter lain misalnya geocode, since_id dan sebagainya. Daftar lengkap parameter <i>Twitter Search API</i> dan format <i>output request</i> bisa dilihat di <a href='https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html'>API references</a>.

# %% [markdown]
# ## Twitter Streaming API
#
# Tweet yang dikumpulkan menggunakan <i>Twitter Streaming API</i> merupakan data <i>tweet</i> yang bersifat <i>real time</i>. Langkah-langkah melakukan pengumpulan data dengan <i>Twitter Streaming API</i> adalah sebagai berikut:
#
# <b>Code 7</b>:

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy import API
from tweepy.streaming import StreamListener
import json
 
consumer_key = 'IaGI9Y9bc33VARK5K4OqgCmNF'
consumer_secret = 'IlzLWseGtVxb2ghlBYY125Fq2yPISiAPui3g31kHRbPSRWKJ17'
access_token = '947706038-co0h4yFWIylo67AQzqfP1RyJTURaa4CWXmDrhNF3'
access_token_secret = 'zhI2DKCJU8rai4gaXQTQItcVmmrC8UnuhN95sLAXtzaX4'

# %% [markdown]
# ### Membuat StreamListener
#
# Kelas `StreamListener` akan memberikan informasi mengenai status <i>request data</i> Twitter yang kita cari. Pada kelas ini, terdapat dua fungsi yaitu fungsi on_data() yang mengembalikan data yang kita <i>request</i> dan fungsi `on_error()` yang memberikan informasi jika <i>request</i> gagal.
#
# Di dalam fungsi `on_data()`, akan didapatkan keluaran <i>json string</i> yang berisi data hasil <i>request</i>. Untuk mendapatkan komponen <i>tweet</i> yang diinginkan, kita perlu melakukan <i>parsing</i> data json tersebut. Sementara itu, fungsi `on_error()` mengembalikan pesan <i>error</i> apabila terdapat <i>error</i> pada <i>request</i>.
#
# <b>Code 8</b>:

# %%
class MyStreamListener(StreamListener):
    def on_data(self, data):
        # keluaran data dalam format json string
        all_data = json.loads(data)
        if "extended_tweet" in all_data:
            fw = open("hasil_tweet_c9.csv", "a", encoding ="utf-8")
            text = all_data["extended_tweet"]["full_text"]
            text = text.replace("\n", " ")
            time_created = all_data["created_at"]
            fw.write("Time created :" + time_created + ", text : " + text + " " +  "\n")
            print(text)
            print('-'*60)
    def on_error(self, status):
        print(status.text)

# %% [markdown]
# ### Membuat stream
#
# Fungsi `Stream` digunakan untuk melakukan <i>request streaming</i> berdasarkan autorisasi dari token API yang kita miliki. Pada fungsi `API()` terdapat parameter tambahan `wait_on_rate_limit=True` dan `wait_on_rate_limit_notify=True` agar program tetap berjalan dan menunggu selama <i>request</i> sudah melebihi <i>limit</i>.
#
# Untuk standar parameter filter yang lain dapat dilihat di halaman <a href='https://developer.twitter.com/en/docs/tweets/filter-realtime/guides/basic-stream-parameters.html'>dokumentasi</a> Twitter.
#
# <b>Code 9</b>:

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True,
          retry_count=10, retry_delay=5, retry_errors=5)
twitterStream = Stream(api.auth, MyStreamListener())
 
twitterStream.filter(track=["makan"], languages=["in"])
# Out:
# “Sebelum ni, saya rasa life saya kosong. Setiap hari tu sama. Malam pun sama. Saya pergi kerja, saya singgah makan, kemudian saya balik rumah. Takde apa yang special. Bertahun-tahun, sama je.“ sambung Bahadur,  Melodi cuba mendengar dengan tekun.
# ------------------------------------------------------------
# Asli seribet itu bawa jalan bayik. Lg makan dia nangis minta nenen, trus lg solat dia nangis ga betah minta ganti popok. Trus baru tau kalo nursery room itu ga boleh masuk cowok😭😭😭  Aku yg selama ini apa2 dibantu suamik &amp; ibu jd agak kagot dikit shay😭
# ------------------------------------------------------------
# "aku sekarang kalo abis makan sering meler" *ambilin tisu sekotaknya ditaruh di pangkuanku  "aku susah ngomong gegara meler" *ditungguin sampe aku selesai beresin trs lanjut ngomong
# ------------------------------------------------------------
# Macam sgt makan sinful foods today. Greasy, high in carbo.. air manis lagi. haha maybe sebab balas dendam habis pkpd &amp; cannot go anywhere sbb kerja
# ------------------------------------------------------------
# @mereshakan ️️️️  ️️️️ ️️ ️️️ ️️ ️️ ️️️ ️️ "Kalau saya makan jengkol pas kamu masih ada kan kamu bakal kebauan dan otomatis ngejauh," ujar Edden tak mau kalah. Ia memang keras kepala perihal perdebatan, bahkan masalah sepele sekalipun. ️️️️  ️️️️
# ------------------------------------------------------------
# Selama 2 tahun di SMA ini, Irzan selalu nyempetin untuk nyamperin ke ruang kelas gue, sekedar ngajak ngobrol dan ketawa bareng, kita sering makan bekel berdua, yang juga kita buat berdua sebelum pergi sekolah. Masih ada fotonya pas dia masak bareng Ibu. https://t.co/px63e2o83N
# ------------------------------------------------------------
# @HEARTSHAPEDIE ㅤㅤ Kamu tau nggak? Habis kamu bilang begini, tidur saya nggak nyenyak. Jadi kebangun gara - gara mimpi si sisi makan anak saya.  ㅤㅤ
# ------------------------------------------------------------
# Kasihku takkan berubah, selalu padamu, dan terus bertambah. Pancarkan segala bencimu padaku, niscaya tak goyang yakinku. Azazil tak akan mampu merayuku tuk berpaling darimu. Bahkan bila sampai seribu kali ia merayu, ia akan jera di makan waktu.
# ------------------------------------------------------------
# @GaluhAgustinaS Bukan takut gendut sih, yg lebih beresiko takut diabet atau lainnya  , karena malam seharusnya rileks , organ tubuh waktunya istirahat , kalo makan yg kerja hanya organ pencernaan doang.
# ------------------------------------------------------------
# ooh begini rasanya kalo ditreat sebegitunya😂🤣, mau ini mau itu tinggal modus update ig story eh masuk notif wa "lari besok deh sdh itu makan bubur" 1 notif sdh mewakili semuanya yg ku mau🌪🌪
# ------------------------------------------------------------
# ketika tidur Suzy sering berbicara, tertawa bahkan teriak tanpa ia sadari.Suzy juga punya kebiasaan tidur di mana saja dan kapan saja. Pernah suatu ketika Suzy tertidur pda saat sedang makan.
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-663d07bc1234> in <module>
#       5 twitterStream = Stream(api.auth, MyStreamListener())
#       6
# ----> 7 twitterStream.filter(track=["makan"], languages=["in"])
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Nomor 3

# %%
tweets3 = extractor.search(
    q="tidur OR siang", lang="id", result_type="popular", count=10, tweet_mode="extended")

print("Jumlah tweet yang berhasil didapatkan: {}.\n".format(len(tweets)))
# Out:
# Jumlah tweet yang berhasil didapatkan: 10.

# %%
fw = open("hasil_tweet_populer1.csv", "w", encoding ="utf-8")
for tweet in tweets3:
    # mendapatkan tweet > 140 chars
    text = tweet.full_text

    # mendapatkan tweet asli yang diretweet
    if hasattr(tweet, "retweeted_status"):
        text = tweet.retweeted_status.full_text
        
    text = text.replace("\n", " ")

    # menuliskan ke dalam file .csv
    fw.write(text +"\n")

fw.close()

# %% [markdown]
# ### Nomor 4

# %%
tweets4 = extractor.search(
    q="tidur -siang", lang="id", result_type="popular", count=10, tweet_mode="extended")

print("Jumlah tweet yang berhasil didapatkan: {}.\n".format(len(tweets)))
# Out:
# Jumlah tweet yang berhasil didapatkan: 10.

# %%
fw = open("hasil_tweet_populer2.csv", "w", encoding ="utf-8")
for tweet in tweets4:
    # mendapatkan tweet > 140 chars
    text = tweet.full_text

    # mendapatkan tweet asli yang diretweet
    if hasattr(tweet, "retweeted_status"):
        text = tweet.retweeted_status.full_text
        
    text = text.replace("\n", " ")

    # menuliskan ke dalam file .csv
    fw.write(text +"\n")

fw.close()

# %% [markdown]
# ### Nomor 5
#
# Pada Operasi OR tepatnya pada file hasil tweet popular 1, Twitter Search mencari tweet yang mengandung kata tidur ataupun siang, sedangkan pada Operasi - hanya mencari tweet yang mengandung kata tidur dan tidak ada kata siang didalamanya

# %% [markdown]
# # Data Collection - Twitter (Twint)
#
# Selain menggunakan Tweepy, pengumpulan data tekstual <i>tweet</i> dapat juga dilakukan dengan menggunakan <i>library</i> <a href='https://github.com/twintproject/twint'>Twint</a>. Perbedaan <i>library</i> ini dengan Tweepy adalah:
# 1. Twint hanya bisa digunakan untuk mengambil data <i>past tweet</i>, namun rentang waktunya tidak terbatas, seperti Tweepy (H-7)
# 2. Tidak membutuhkan <i>access token</i> Twitter API.
#
# Berikut merupakan contoh penggunaan Twint dalam melakukan <i>crawling tweet</i>:

# %%
# import library
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = 'banjir' # masukkan kata kunci
c.Since = '2021-02-20 00:00:00'
c.Until = '2021-02-20 00:05:00' 
c.Store_csv = True
c.Output = 'banjir.csv'
c.Hide_output = True

twint.run.Search(c)

# %% [markdown]
# # Data Collection - Twecoll
#
# Pada tutorial kali ini, akan dibahas tentang langkah-langkah untuk mengetahui <i>friends-of-friends network</i>. Analisis <i>friends-of-friends</i> merupakan analisis yang dilakukan pada
# jaringan media sosial yang bertujuan untuk mengetahui jaringan pertemanan. Pada tutorial
# ini, akan dilakukan pengumpulan data jaringan <i>friends-of-friends</i> dari Twitter dengan
# menggunakan Twecoll.
#
# Langkah-langkah untuk untuk mengambil data pertemanan menggunakan Twecoll adalah
# sebagai berikut:
# 1. Masuk ke direktori dari twecoll dan eksekusi perintah berikut:<br>
# ```
# python twecoll init <USERNAME_TWITTER_TARGET>
# ```
# Setelah selesai akan dihasilkan berkas .dat dengan format <USERNAME_TWITTER_TARGET>.dat
#
# 2. Ketika baru dijalankan pertama kali, maka program akan meminta <i>consumer secret</i> dan
# <i>consumer key</i>. Masukkan <i>consumer secret</i> dan <i>consumer key</i> masing-masing.
#
# 3. Setelah terverifikasi, program akan mengarahkan ke <i>browser</i> yang berisi PIN. Berikut
# adalah contoh halaman yang menampilkan PIN.
# <img src='images/image2.png'></img>
# Masukkan PIN yang ditampilkan di <i>browser</i> ke dalam program.
#
# 4. Setelah selesai, eksekusi perintah berikut:
# ```
# python twecoll fetch <USERNAME_TWITTER_TARGET>
# ```
# Proses ini akan menghasilkan suatu berkas berekstensi .f di dalam folder fdat yang
# berisi daftar <i>user id</i> pada jaringan <i>friends-of-friends</i>. Untuk mengunduh data ini,
# diperlukan waktu sekitar 5-6 jam (bisa lebih lama, tergantung jumlah
# <i>follower</i>/<i>following</i> target). Hal ini disebabkan oleh <i>rate limit</i> dari Twitter API yang hanya memberikan akses data sebanyak 15 <i>requests</i> per 15 menit.
#
# 5. Setelah selesai, eksekusi perintah berikut:
# ```
# python twecoll edgelist <USERNAME_TWITTER_TARGET>
# ```
# Perintah tersebut akan membentuk daftar <i>edge</i> dari daftar pertemanan yang sudah
# disimpan dalam folder fdat. Keluaran dari perintah ini adalah berupa berkas .gml
# dengan format <USERNAME_TWITTER_TARGET>.gml. Berikut adalah contoh isi berkas
# .gml dari <i>username</i> target “najwashihab”
# <img src='images/image4.png'></img>
#
# Untuk dapat melihat visualisasi antar <i>nodes</i>, berkas .gml pada langkah 5 dapat dibuka dengan menggunakan <i>graph processing tools</i> seperti Gephi atau dengan Python <i>library</i>, misalnya NetworkX dan igraph. Berikut adalah cara memvisualisikan berkas .gml pada Gephi:
#
# 1. Saat membuka file .gml untuk pertama kali, akan muncul tampilan seperti ini
# <img src='images/image3.png'></img>
#
# 2. Mengatur layout
# Graf yang ditunjukkan tidak beraturan dan susah untuk dianalisis. Di dalam Gephi
# terdapat beberapa <i>plugins</i> yang dapat digunakan untuk merepresentasikan kembali graf
# menjadi lebih terkelompok dan membuat <i>node</i> menjadi mudah untuk dilihat. <i>Layout</i>
# dapat diakses pada <i>box</i> pada pojok kiri bawah dari layar Gephi.
# <img src='images/image6.png'></img>
#
# 3. Jika Anda klik dropdown `---Choose Layout`, maka akan muncul beberapa pilihan algoritma yang dapat dipilih seperti Force Atlas, Yifan Hu, dan lain-lain. Coba Anda pilih algoritma Force Atlas lalu <i>click</i> `Run`. Setelah beberapa saat lalu klik `Stop`, maka graf akan bergerak.
# <img src='images/image5.png'></img>
#
# 4. Anda dapat menginstal beberapa plugins tambahan untuk visualisasi layout dengan
# masuk ke dalam <i>Tools</i> lalu <i>Plugins</i>.
#
# <i>Disclaimer</i>: Tidak ada tugas visualisasi <i>network</i> yang diujikan pada tutorial ini, namun hal tersebut akan berguna untuk <i>midterm project</i>.

# %% [markdown]
# # Data Collection - Linkedin
#
# Salah satu cara untuk melakukan <i>scraping</i> data dari Linkedin adalah dengan menggunakan <i>library</i> Linkedin Scraper. Cara instalasi dan contoh penggunaan dapat teman-teman eksplor sendiri dari <a href="https://pypi.org/project/linkedin-scraper/">halaman dokumentasi</a> <i>library</i> tersebut.
#
# <i>Library</i> Linkedin Scraper menggunakan <i>library</i> <i>Selenium</i> dalam melakukan <i>scraping</i> data. Jadi, sebelum memulai <i>scraping</i> Anda perlu mengunduh chromedriver sesuai dengan versi Chrome dan OS yang Anda gunakan. Chromedriver dapat diunduh pada halaman <a href="https://chromedriver.chromium.org/downloads">berikut</a>.
#
# Berikut merupakan contoh kode yang digunakan untuk mengambil data dari suatu akun.

# %%
from linkedin_scraper import Person, actions
from selenium import webdriver

# masukkan path ke chrome driver
driver = webdriver.Chrome(
    "")

email = "" # masukkan email akun Linkedin
password = "" # masukkan password akun Linkedin
actions.login(driver, email, password)
person = Person("", driver=driver, scrape=True) # masukkan url Linkedin Anda

# %%
person

# %% [markdown]
# # Data Collection - Web Scraping
#
# <i>Website</i> yang akan kita coba ambil datanya adalah alodokter.com, khususnya halaman <a href='https://www.alodokter.com/komunitas/diskusi/penyakit'>`Tanya Dokter`</a>. Kita akan mencoba mengambil data judul diskusi, penanya, dan pemberi balasan diskusi di halaman 2 (url: https://www.alodokter.com/komunitas/diskusi/penyakit/page/2) dengan menggunakan <i>library</i> Selenium.

# %%
# import library
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %% [markdown]
# <b>Code 10</b>:

# %%
# masukkan path ke chrome driver
driver = webdriver.Chrome(
    "C:/Users/ASUS/chromedriver_win32/chromedriver.exe")
page = 2
url = "https://www.alodokter.com/komunitas/diskusi/penyakit/page/{}".format(page)
driver.get(url)
WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located(
    (By.XPATH, '//div[@id="topic-list"]/*')))
arr_cards = driver.find_elements_by_xpath('//div[@id="topic-list"]/*')
print('Banyak diskusi:', len(arr_cards))
df_scrape = pd.DataFrame()
for c in arr_cards:
    judul = c.get_attribute("title")
    penanya = c.get_attribute("username")
    pemberi_balasan = c.get_attribute("pickup-name")
    slug = c.get_attribute("href")
    df_scrape = df_scrape.append({
        "slug" : slug,
        "penanya": penanya,
        "pemberi_balasan": pemberi_balasan,
        "judul": judul
    }, ignore_index=True)
df_scrape.to_csv("df_scrape_page_{}.csv".format(page), index=False)
# Out:
# Banyak diskusi: 15

# %%
df_scrape
# Out:
#                                                 judul  \
# 0   Bolehkah meminum ambeven saat Gerd dan mengkon...
# 1        Obat bisul yang aman untuk ibu hamil 6 bulan
# 2                                     Akurasi Tes HIV
# 3                    Mengapa saya telat haid 6 bulan?
# 4                  Tips minum obat tablet + overdosis
# 5                                          Vaksin pcv
# 6                                             Depresi
# 7                                           Imunisasi
# 8                                      Alergi protein
# 9                                          mata minus
# 10                                    Flek pendarahan
# 11  Sudah 5 Tahun operasi tiroid, efek kalau minum...
# 12                         Normal kah visus mata 9/5?
# 13  Tespek 3 kali hasil positif, tapi keluar berca...
# 14                           Tidak haid selama 9bulan
#
#                  pemberi_balasan                    penanya  \
# 0               dr. Riza Marlina              dwi setyo aji
# 1                                                      Tio
# 2                                                      Roy
# 3                                              Retha Junita
# 4                                                      Zul
# 5                                                      Gea
# 6                   dr. Caroline            Janjan Nurjanah
# 7     dr.Tabita Padmaya Setiawan             Naning Safitri
# 8     dr.Tabita Padmaya Setiawan                  KhusnulS
# 9     dr.Tabita Padmaya Setiawan            Wahyu Ramadhani
# 10    dr.Tabita Padmaya Setiawan                      Dara
# 11                  dr. Caroline                    yunita
# 12    dr.Tabita Padmaya Setiawan  Lastri Lurianti Sihombing
# 13                  dr. Caroline              Indra Lestari
# 14  dr. Farah Shafira Zulkarnain         Dessy Fitri Monica
#
#                                                  slug
# 0   /komunitas/topic/bolehkah-meminum-ambeven-saat...
# 1   /komunitas/topic/obat-bisul-yang-aman-untuk-ib...
# 2                    /komunitas/topic/akurasi-tes-hiv
# 3   /komunitas/topic/mengapa-saya-telat-haid-6-bulan-
# 4   /komunitas/topic/tips-minum-obat-tablet---over...
# 5                   /komunitas/topic/vaksin-pcvcab334
# 6                      /komunitas/topic/depresi7bf1ce
# 7                    /komunitas/topic/imunisasif0b970
# 8               /komunitas/topic/alergi-proteina713df
# 9                   /komunitas/topic/mata-minus55c17d
# 10                   /komunitas/topic/flek-pendarahan
# 11  /komunitas/topic/sudah-5-tahun-operasi-tiroid-...
# 12        /komunitas/topic/normal-kah-visus-mata-9-5-
# 13  /komunitas/topic/tespek-3-kali-hasil-positif--...
# 14          /komunitas/topic/tidak-haid-selama-9bulan

# %% [markdown]
# Selain dengan menggunakan Selenium, kita juga bisa melakukan <i>scraping</i> data menggunakan <i>library</i> Requests. Bedanya dengan Selenium, <i>library</i> ini terbatas hanya dapat melakukan <i>scraping</i> pada <i>web</i> yang tidak begitu kompleks (bukan <i>web </i>berbasis <i>Javascript Core</i>). Berikut merupakan contoh penggunaan <i>Requests</i> dengan bantuan <i>library</i> BeautifulSoup untuk melakukan <i>scraping</i> halaman daftar obat pada <i>website</i> hellosehat.com

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get('https://hellosehat.com/obatan-suplemen/obat/')
soup = BeautifulSoup(page.content, 'lxml')
arr_obat = soup.findAll('div', {'class': 'hb-hc-small-list-content'})
arr_obat_str = []
for o in arr_obat:
    arr_obat_str.append(o.find('span').text)

# %%
from collections import Counter

Counter(arr_obat_str).most_common()
# Out:
# [('Betadine', 2),
#  ('Brufen', 2),
#  ('Daktarin', 2),
#  ('Duspatalin', 2),
#  ('Forumen', 2),
#  ('Fucidin', 2),
#  ('Garamycin', 2),
#  ('Glucophage', 2),
#  ('Isprinol', 2),
#  ('Lopid', 2),
#  ('Methycobal', 2),
#  ('Micardis', 2),
#  ('Ryzen', 2),
#  ('Stilnox', 2),
#  ('Vitacid', 2),
#  ('Voltaren', 2),
#  ('Vometa', 2),
#  ('Zinacef', 2),
#  ('A Scabs', 1),
#  ('Aafact', 1),
#  ('Abbotic/Abbotic Granul/A', 1),
#  ('Abirom', 1),
#  ('Abixim', 1),
#  ('Abufen C', 1),
#  ('Acamprosate', 1),
#  ('Acarbose', 1),
#  ('Aceclofenac', 1),
#  ('Acelamine', 1),
#  ('Acemetacin', 1),
#  ('Acendril', 1),
#  ('Acenor-M', 1),
#  ('Acepress', 1),
#  ('Acetazolamide', 1),
#  ('Acetensa', 1),
#  ('Acetyl Spiramycin Kyowa', 1),
#  ('Acetylcysteine', 1),
#  ('Aciblock', 1),
#  ('Acilaz', 1),
#  ('Acitretin', 1),
#  ('Aclonac', 1),
#  ('Acne Feldin', 1),
#  ('Acpulsif 5', 1),
#  ('Acran', 1),
#  ('Acrivastine', 1),
#  ('Actabone', 1),
#  ('Actacef', 1),
#  ('Actaryl', 1),
#  ('Actaxon', 1),
#  ('Actifed', 1),
#  ('Activated Charcoal', 1),
#  ('Actoplatin', 1),
#  ('Actoplus Met', 1),
#  ('Actos', 1),
#  ('Acyclovir', 1),
#  ('Adalat', 1),
#  ('Adalat OROS', 1),
#  ('Adant Dispo', 1),
#  ('Adapalene', 1),
#  ('Adecco', 1),
#  ('Adona (AC-17)/Adona (AC-17) Forte', 1),
#  ('Adrenalini Bitartras', 1),
#  ('Adrome', 1),
#  ('Advantan', 1),
#  ('Aerius', 1),
#  ('Aerrane', 1),
#  ('Aethylcarbonas Chinin (Euchinin)', 1),
#  ('Afrin', 1),
#  ('Afucid', 1),
#  ('Aggravan', 1),
#  ('Agrelano', 1),
#  ('Agrezol', 1),
#  ('Akrofen', 1),
#  ('Akurza', 1),
#  ('Albapure 20', 1),
#  ('Albendazole', 1),
#  ('Albiglutide', 1),
#  ('Albiotin', 1),
#  ('Albothyl', 1),
#  ('Albucid', 1),
#  ('Albuman 20%', 1),
#  ('Albumin-Human 20%', 1),
#  ('Albuminar-25', 1),
#  ('Alburaas', 1),
#  ('Albutein', 1),
#  ('Alclofenac', 1),
#  ('Alclometasone', 1),
#  ('Alco Drop', 1),
#  ('Alco/Alco Plus/Alco Plus DMP', 1),
#  ('Alcon Cilox', 1),
#  ('Aldactone', 1),
#  ('Aldapres', 1),
#  ('Aldesleukin', 1),
#  ('Aldiab', 1),
#  ('Aldin', 1),
#  ('Aldomer', 1),
#  ('Alendronic Acid', 1),
#  ('Alermax', 1),
#  ('Alernitis', 1),
#  ('Aleros', 1),
#  ('Alexan', 1),
#  ('Alfentanil', 1),
#  ('Alflam', 1),
#  ('Alimemazine', 1),
#  ('Alimta', 1),
#  ('Alinamin F', 1),
#  ('Alista', 1),
#  ('Alkeran', 1),
#  ('Alkohol 70 Persen', 1),
#  ('Allergy Relief', 1),
#  ('Allogon', 1),
#  ('Allohex', 1),
#  ('Allopurinol', 1),
#  ('Alloris', 1),
#  ('Allylestrenol', 1),
#  ('Alminoprofen', 1),
#  ('Almitrine', 1),
#  ('Alogliptin', 1),
#  ('Alomide', 1),
#  ('Alopros', 1),
#  ('Aloxid', 1),
#  ('Aloxiprin', 1),
#  ('Aloxtra', 1),
#  ('Alpain', 1),
#  ('Alpentin', 1),
#  ('Alpha Lipoic Acid', 1),
#  ('Alphadine', 1),
#  ('Alphadine Obat Kumur Alp', 1),
#  ('Alphagesic', 1),
#  ('Alphahist', 1),
#  ('Alphamid', 1),
#  ('Alphamol', 1),
#  ('Alprazolam', 1),
#  ('Alprostadil', 1),
#  ('Altofen', 1),
#  ('Aluminium Hidroksida (Alumunium Hydroxide)', 1),
#  ('Aluvia', 1),
#  ('Alverine', 1),
#  ('Alxil', 1),
#  ('Alzim', 1),
#  ('Amaryl', 1),
#  ('Ambeven', 1),
#  ('Ambroxol', 1),
#  ('Amcinonide', 1),
#  ('Amerol', 1),
#  ('Amfetamin', 1),
#  ('Amikacin', 1),
#  ('Aminofilin', 1),
#  ('Amiodaron', 1),
#  ('Amisulpride', 1),
#  ('Amitriptyline', 1),
#  ('Amlodipine', 1),
#  ('Ammonium Chloride (Amonium Klorida)', 1),
#  ('Amobarbital', 1),
#  ('Amoxicillin', 1),
#  ('Ampicillin', 1),
#  ('Amtocort', 1),
#  ('Anacaine', 1),
#  ('Anafen', 1),
#  ('Anafranil', 1),
#  ('Anakinra', 1),
#  ('Analgesik', 1),
#  ('Analsik', 1),
#  ('Analspec', 1),
#  ('Anatensol', 1),
#  ('Anbacim', 1),
#  ('Ancefa', 1),
#  ('Andalan Injeksi Andalan', 1),
#  ('Andalpha', 1),
#  ('Andantol', 1),
#  ('Andep', 1),
#  ('Androcur', 1),
#  ('Androlon', 1),
#  ('Anelat', 1),
#  ('Anemolat', 1),
#  ('Anerocid', 1),
#  ('Anesfar', 1),
#  ('Anesject', 1),
#  ('Anexia', 1),
#  ('Anexin', 1),
#  ('Anfix', 1),
#  ('Anfuhex', 1),
#  ('Anfuhex Krim Anfuhex Cre', 1),
#  ('Angioten', 1),
#  ('Anhissen', 1),
#  ('Anistreplase', 1),
#  ('Anitid', 1),
#  ('Anlos', 1),
#  ('Anmerob', 1),
#  ('Anore', 1),
#  ('Anpiride', 1),
#  ('Anrema Anrema 50/Anrema', 1),
#  ('Ansi', 1),
#  ('Antalgin', 1),
#  ('Antangin', 1),
#  ('Anthramed', 1),
#  ('Antidine', 1),
#  ('Antimo', 1),
#  ('Antimo Anak', 1),
#  ('Antiplat', 1),
#  ('Antipres', 1),
#  ('Antiprestin', 1),
#  ('Anuva', 1),
#  ('Anxibloc', 1),
#  ('Anzatax', 1),
#  ('Apa Hammer of Thor (Suplemen Pembesar Penis) Benar Efektif?', 1),
#  ('Apakah Boleh Minum Obat Pakai Teh?', 1),
#  ('Apeton', 1),
#  ('Apidra', 1),
#  ('Apolar', 1),
#  ('Aprion', 1),
#  ('Aprovel', 1),
#  ('Araclof', 1),
#  ('Arava', 1),
#  ('Arbiten-I', 1),
#  ('Arclate', 1),
#  ('Arcodryl', 1),
#  ('Arcored', 1),
#  ('Arcoxia', 1),
#  ('Ardium', 1),
#  ('Arespin', 1),
#  ('Arfen', 1),
#  ('Aricept', 1),
#  ('Aricept Evess', 1),
#  ('Arimed', 1),
#  ('Arkine', 1),
#  ('Armolev 500', 1),
#  ('Arnid', 1),
#  ('Aromasin', 1),
#  ('Arsigran', 1),
#  ('Arsitam', 1),
#  ('Arsitrocin', 1),
#  ('Artane', 1),
#  ('Arteoptic LA', 1),
#  ('Artepid', 1),
#  ('Arthrifen/Arthrifen Forte', 1),
#  ('Artricom', 1),
#  ('Artrilox', 1),
#  ('Asabium', 1),
#  ('Asam Asetat', 1),
#  ('Asam Clodronic (Clodronic Acid)', 1),
#  ('Asam Cromoglicic', 1),
#  ('Asam Folat', 1),
#  ('Asam Fusidat (Fusidic Acid)', 1),
#  ('Asam Laktat (Lactic Acid)', 1),
#  ('Asam Mefenamat (Mefenamic Acid)', 1),
#  ('Asam Mefenamat Indo Farma', 1),
#  ('Asam Mefenamat Landson', 1),
#  ('Asam Pantotenat', 1),
#  ('Asam Salisilat', 1),
#  ('Asam Traneksamat', 1),
#  ('Asam Valproat (Valproic Acid)', 1),
#  ('Asamnex', 1),
#  ('Ascardia', 1),
#  ('Ascarzan', 1),
#  ('Ascomin', 1),
#  ('Asepta', 1),
#  ('Asimat', 1),
#  ('Asmacare', 1),
#  ('Aspil', 1),
#  ('Aspilets', 1),
#  ('Aspir 81', 1),
#  ('Aspirin', 1),
#  ('Astharol', 1),
#  ('Atarax', 1),
#  ('Atenolol', 1),
#  ('Ativan', 1),
#  ('Atorvastatin', 1),
#  ('Atranac', 1),
#  ('Atrocox 7.5/Atrocox 15', 1),
#  ('Atropin (Atropine)', 1),
#  ('Atussin', 1),
#  ('Avandamet', 1),
#  ('Avandaryl', 1),
#  ('Avandia', 1),
#  ('Avelox', 1),
#  ('Avigan (Favipiravir)', 1),
#  ('Avloclor', 1),
#  ('Avocel', 1),
#  ('Avodart', 1),
#  ('Axcel Fungicort', 1),
#  ('Azelastine', 1),
#  ('Azithromycin', 1),
#  ('Azlocillin', 1),
#  ('Azmacon', 1),
#  ('Azol', 1),
#  ('Bacbutol', 1),
#  ('Bacitracin', 1),
#  ('Bactazon', 1),
#  ('Bactigras', 1),
#  ('Bactiprox', 1),
#  ('Bactirom', 1),
#  ('Bactoderm', 1),
#  ('Bactoprim Combi Bactopri', 1),
#  ('Bactraz', 1),
#  ('Bactricid Bactricid/Bact', 1),
#  ('Bactrim/Bactrim Forte', 1),
#  ('Bactrizol Bactrizol/Bact', 1),
#  ('Bactroban', 1),
#  ('Bagaimana Cara Kerja Obat Antibiotik Melawan Bakteri?', 1),
#  ('Bagaimana Cara Mengenali Obat Palsu?', 1),
#  ('Bahaya Mengonsumsi Alkohol Setelah Minum Obat', 1),
#  ('Bahaya Minum Paracetamol Setelah Minum Minuman Beralkohol', 1),
#  ('Balticin', 1),
#  ('Bamgetol', 1),
#  ('Banadoz', 1),
#  ('Baquinor Tetes Mata Baqu', 1),
#  ('Baquinor/Baquinor Forte', 1),
#  ('Barzepin', 1),
#  ('Batrafen', 1),
#  ('Baxima', 1),
#  ('Beclov', 1),
#  ('Belerang (Sulfur)', 1),
#  ('Bellatram', 1),
#  ('Benadryl', 1),
#  ('Benarkah Minum Ibuprofen Dosis Tinggi Bisa Bikin Telat Datang Bulan?', 1),
#  ('Benodin', 1),
#  ('Benofat', 1),
#  ('Benofomin', 1),
#  ('Benomet 300', 1),
#  ('Benostan', 1),
#  ('Benzocaine', 1),
#  ('Benzodent', 1),
#  ('Benzoyl Peroxide (Benzoil Peroksida)', 1),
#  ('Bepanthen', 1),
#  ('Berapa Banyak Dosis Aman Minum Obat Pereda Nyeri?', 1),
#  ('Berbagai Jenis Obat Pereda Mual Sesuai Penyebabnya', 1),
#  ('Berbagai Makanan yang Bisa Mengganggu Kerja Obat Dalam Tubuh', 1),
#  ('Berlicort', 1),
#  ('Berlison', 1),
#  ('Bernesten', 1),
#  ('Bernoflox', 1),
#  ('Berocca', 1),
#  ('Berotec', 1),
#  ('Bersol', 1),
#  ('Berthyco', 1),
#  ('Bestalin', 1),
#  ('Bestypro', 1),
#  ('Betadine Obat Kumur', 1),
#  ('Betadine Obat Kumur Beta', 1),
#  ('Betadine Preparat Vagina', 1),
#  ('Betadine Shampoo', 1),
#  ('Betahistine', 1),
#  ('Betalans', 1),
#  ('Betametason (Betamethasone)', 1),
#  ('Betarhin', 1),
#  ('Betrix', 1),
#  ('Biatron', 1),
#  ('Bicrolid', 1),
#  ('Bidicef', 1),
#  ('Bifotik', 1),
#  ('Bio-E 200', 1),
#  ('Biocef', 1),
#  ('Biocepime', 1),
#  ('Biocream', 1),
#  ('Biodasin', 1),
#  ('Biodroxil', 1),
#  ('Biogesic', 1),
#  ('Biogrisin', 1),
#  ('Biolincom', 1),
#  ('Bionect', 1),
#  ('Bioplacenton', 1),
#  ('Bioprexum', 1),
#  ('Bioprom', 1),
#  ('Bioquin/Bioquin Forte', 1),
#  ('Biorazon', 1),
#  ('Biotriax', 1),
#  ('Bioxon', 1),
#  ('Biozim', 1),
#  ('Biperiden', 1),
#  ('Bisacodyl', 1),
#  ('Bisoltussin', 1),
#  ('Bisolvon', 1),
#  ('Bisoprolol', 1),
#  ('Bledstop', 1),
#  ('Blesifen', 1),
#  ('Blistra', 1),
#  ('Blopress', 1),
#  ('Blorec', 1),
#  ('Bodrex', 1),
#  ('Bodrex Forte', 1),
#  ('Bondronat', 1),
#  ('Bonefos', 1),
#  ('Bonviva', 1),
#  ('Brainact', 1),
#  ('Brainolin', 1),
#  ('Bralifex', 1),
#  ('Bralin', 1),
#  ('Bramin', 1),
#  ('Braxidin', 1),
#  ('Brazine', 1),
#  ('Breathy', 1),
#  ('Brexel', 1),
#  ('Bricasma', 1),
#  ('Broadced', 1),
#  ('Bromax', 1),
#  ('Bromhexine', 1),
#  ('Bromocriptine', 1),
#  ('Bronchophylin', 1),
#  ('Bronchosal', 1),
#  ('Brondisal 2/Brondisal 4', 1),
#  ('Bronsolvan', 1),
#  ('Brospec', 1),
#  ('Brospec 1000', 1),
#  ('Brotizolam', 1),
#  ('Bucain', 1),
#  ('Bucillamine', 1),
#  ('Buclizine', 1),
#  ('Budenofalk', 1),
#  ('Budesonide', 1),
#  ('Bufabron', 1),
#  ('Bufacomb IOB', 1),
#  ('Bufaflam Emulgel', 1),
#  ('Bufect/Bufect Forte', 1),
#  ('Buflomedil', 1),
#  ('Bulaquine', 1),
#  ('Bumetanide', 1),
#  ('Bunascan Spinal 0.5% Heavy', 1),
#  ('Bupivacaine', 1),
#  ('Bupropion', 1),
#  ('Burnazin', 1),
#  ('Buscopan', 1),
#  ('Buscotica', 1),
#  ('Buspar', 1),
#  ('Buspirone', 1),
#  ('Butenafine', 1),
#  ('Butoconazole', 1),
#  ('Buvanest 0.5%', 1),
#  ('Buvanest Spinal 0.5% Heavy', 1),
#  ('Buventol Easyhaler', 1),
#  ('Cabergoline', 1),
#  ('Cafcit', 1),
#  ('Caffeine', 1),
#  ('Calacort', 1),
#  ('Calamine', 1),
#  ('Calapol Calapol/Calapol', 1),
#  ('Calcianta', 1),
#  ('Calcipotriol', 1),
#  ('Calcitonin', 1),
#  ('Calcitriol', 1),
#  ('Calcium', 1),
#  ('Calcium Carbonate + Vitamin D3', 1),
#  ('Calcium Citrate + Vitamin D3', 1),
#  ('Calcium Folinate Ebewe', 1),
#  ('Calcium Lactate (Kalsium Laktat)', 1),
#  ('Calcium Lactate Nufarindo', 1),
#  ('Calcium Sandoz', 1),
#  ('Calciumlevofolinat Ebewe', 1),
#  ('Calcrem', 1),
#  ('Calnat', 1),
#  ('Calorex Drops', 1),
#  ('Calos', 1),
#  ('Calsan', 1),
#  ('Calsical', 1),
#  ('CalSource/CalSource Forte/CalSource Plus Vitamin C/CalSource Junior', 1),
#  ('Caltrate 600 +D', 1),
#  ('Caltum', 1),
#  ('Cameloc', 1),
#  ('Camigesic Camigesik', 1),
#  ('Campain', 1),
#  ('Campto', 1),
#  ('Canagliflozin', 1),
#  ('Candazole', 1),
#  ('Canderin', 1),
#  ('Candesartan', 1),
#  ('Candesartan TI', 1),
#  ('Candipar', 1),
#  ('Candistin', 1),
#  ('Candotens', 1),
#  ('Canesten Bubuk Canesten', 1),
#  ('Canesten Canesten SD/Can', 1),
#  ('Canesten Krim Canesten C', 1),
#  ('Capecitabine', 1),
#  ('Caprazol', 1),
#  ('Caprenafil', 1),
#  ('Caprenem', 1),
#  ('Caprifim', 1),
#  ('Capritazin', 1),
#  ('Caprocef', 1),
#  ('Caprol', 1),
#  ('Capsaicin', 1),
#  ('Captensin', 1),
#  ('Captodiame', 1),
#  ('Captopril', 1),
#  ('Captopril dan Hydrochlorothiazide', 1),
#  ('Captopril Hexpharm', 1),
#  ('Captopril Indo Farma', 1),
#  ('Captopril Landson', 1),
#  ('Carbamazepine', 1),
#  ('Carbamazepine Indo Farma', 1),
#  ('Carbazochrome', 1),
#  ('Carbimazole', 1),
#  ('Carbloxal', 1),
#  ('Carbocisteine', 1),
#  ('Carbomer', 1),
#  ('Carboplatin', 1),
#  ('Carboplatin DBL', 1),
#  ('Carboplatin Ebewe', 1),
#  ('Carboplatin Kalbe', 1),
#  ('Carboplatine Merck', 1),
#  ('Carboprost', 1),
#  ('Carbosin Combiphar/Pharmachemie', 1),
#  ('Carcan', 1),
#  ('Cardace', 1),
#  ('Cardiject', 1),
#  ('Cardiocom', 1),
#  ('Cardiotone', 1),
#  ('Cardiover', 1),
#  ('Cardismo', 1),
#  ('Cardyne', 1),
#  ('Carisoprodol', 1),
#  ('Carmed', 1),
#  ('Caronem', 1),
#  ('Caroverine', 1),
#  ('Carpiaton-25/Carpiaton-100', 1),
#  ('Carsive', 1),
#  ('Carteolol', 1),
#  ('Cartos', 1),
#  ('Carvedilol', 1),
#  ('Caspofungin', 1),
#  ('Cataflam', 1),
#  ('Cataflam Fast', 1),
#  ('Cataflam Tetes Cataflam', 1),
#  ('Cataflam/Cataflam D', 1),
#  ('Catanac', 1),
#  ('Catapres', 1),
#  ('Caviplex', 1),
#  ('Cazetin', 1),
#  ('CDR (Calcium D Redoxon)', 1),
#  ('Cealb', 1),
#  ('Cedantron/Cedantron Siru', 1),
#  ('Cedocard/Cedocard Retard', 1),
#  ('Cefabiotic', 1),
#  ('Cefacef', 1),
#  ('Cefaclor', 1),
#  ('Cefadroxil', 1),
#  ('Cefadroxil Hexpharm', 1),
#  ('Cefadroxil Indo Farma', 1),
#  ('Cefadroxil Soho', 1),
#  ('Cefalexin', 1),
#  ('Cefalotin', 1),
#  ('Cefamandole', 1),
#  ('Cefarin', 1),
#  ('Cefarox', 1),
#  ('Cefat', 1),
#  ('Cefatrizine', 1),
#  ('Cefaxon', 1),
#  ('Cefazol', 1),
#  ('Cefazolin', 1),
#  ('Cefazolin Indo Farma', 1),
#  ('Cefazolin OGBdexa', 1),
#  ('Cefdime', 1),
#  ('Cefdinir', 1),
#  ('Cefditoren', 1),
#  ('Cefemet', 1),
#  ('Cefepime', 1),
#  ('Cefepime Hexpharm', 1),
#  ('Cefetamet', 1),
#  ('Cefika', 1),
#  ('Cefila', 1),
#  ('Cefim', 1),
#  ('Cefinov', 1),
#  ('Cefir', 1),
#  ('Cefixime', 1),
#  ('Cefixime Hexpharm', 1),
#  ('Cefixime OGB Dexa Medica', 1),
#  ('Cefixime OGB Medikon', 1),
#  ('Cefixstar', 1),
#  ('Cefizox', 1),
#  ('Cefmenoxime', 1),
#  ('Cefmer 1', 1),
#  ('Cefmetazole', 1),
#  ('Cefnos', 1),
#  ('Cefobactam DI', 1),
#  ('Cefobet', 1),
#  ('Cefobid', 1),
#  ('Cefoject', 1),
#  ('Cefomax', 1),
#  ('Cefoperazone', 1),
#  ('Cefoperazone Yarindo', 1),
#  ('Cefoperazone/Sulbactam Kalbe', 1),
#  ('Cefophar', 1),
#  ('Cefor', 1),
#  ('Ceforim', 1),
#  ('Cefotaxime', 1),
#  ('Cefotaxime + Sulbactam', 1),
#  ('Cefotaxime Hexpharm', 1),
#  ('Cefotaxime Indo Farma', 1),
#  ('Cefovell', 1),
#  ('Cefoxitin', 1),
#  ('Cefpirome Hexpharm', 1),
#  ('Cefpirome Phapros', 1),
#  ('Cefradol', 1),
#  ('Cefratam', 1),
#  ('Cefriex', 1),
#  ('Cefrin', 1),
#  ('Cefrom', 1),
#  ('Cefsix', 1),
#  ('Cefspan', 1),
#  ('Ceftamax', 1),
#  ('Ceftazidime', 1),
#  ('Ceftazidime Hexpharm', 1),
#  ('Ceftazidime OGB Dexa', 1),
#  ('Ceftazidime Phapros', 1),
#  ('Ceftibuten', 1),
#  ('Ceftien', 1),
#  ('Ceftigra', 1),
#  ('Ceftiz', 1),
#  ('Ceftriaxone', 1),
#  ('Ceftriaxone Hexpharm', 1),
#  ('Ceftriaxone Indo Farma', 1),
#  ('Ceftricor', 1),
#  ('Ceftrimax', 1),
#  ('Ceftrimet', 1),
#  ('Ceftrox', 1),
#  ('Ceftum', 1),
#  ('Cefuroxime', 1),
#  ('Cefxon', 1),
#  ('Celebrex', 1),
#  ('Celecoxib', 1),
#  ('Celestamine', 1),
#  ('Celiprolol', 1),
#  ('Celocid Dexa Medica', 1),
#  ('Celocid Ferron', 1),
#  ('Celodim', 1),
#  ('Cendo Lyteers', 1),
#  ('Cendo Xitrol', 1),
#  ('Centrasic', 1),
#  ('Cepezet', 1),
#  ('Cephaflox', 1),
#  ('Cephalexin Indo Farma', 1),
#  ('Cepraz', 1),
#  ('Ceptik', 1),
#  ('Ceradolan', 1),
#  ('Cerafix', 1),
#  ('Cerazette', 1),
#  ('Cercul', 1),
#  ('Cerebrovit', 1),
#  ('Ceremax', 1),
#  ('Cerini', 1),
#  ('Cerivastatin Sodium', 1),
#  ('Ceropid', 1),
#  ('Cerozon', 1),
#  ('Cetabrium', 1),
#  ('Cetabutol', 1),
#  ('Cetacycline-P', 1),
#  ('Cetadop', 1),
#  ('Cetafloxo', 1),
#  ('Cetalmic', 1),
#  ('Cetapain', 1),
#  ('Cetasix', 1),
#  ('Cetathrocin', 1),
#  ('Cetatrex', 1),
#  ('Cetazum', 1),
#  ('Ceteron', 1),
#  ('Cethixime', 1),
#  ('Cetinal', 1),
#  ('Cetirizine', 1),
#  ('Cetirizine + Pseudoephedrine', 1),
#  ('Cetirizine Hexpharm', 1),
#  ('Cetirizine OGB', 1),
#  ('Cetivar', 1),
#  ('Cetrimide', 1),
#  ('Cetrimide + Chlorhexidine', 1),
#  ('Cetrixal', 1),
#  ('Cetrol', 1),
#  ('Cetrorelix', 1),
#  ('Cetrotide', 1),
#  ('Cetuximab', 1),
#  ('Cetylpyridinium Chloride', 1),
#  ('Cetymin', 1),
#  ('Chenodiol (Chenodeoxycholic Acid)', 1),
#  ('Chirocaine', 1),
#  ('Chlor-Trimeton', 1),
#  ('Chloral Hydrate', 1),
#  ('Chlorambucil', 1),
#  ('Chloramex', 1),
#  ('Chloramphenicol', 1),
#  ('Chloramphenicol Eye Drops Indo Farma', 1),
#  ('Chloramphenicol Indo Farma', 1),
#  ('Chlorcyclizine', 1),
#  ('Chlordiazepoxide', 1),
#  ('Chlordiazepoxide + Clidinium', 1),
#  ('Chlorhexidine', 1),
#  ('Chlormadinone', 1),
#  ('Chloroquine', 1),
#  ('Chloroquine Indo Farma', 1),
#  ('Chlorothiazide', 1),
#  ('Chlorphenamine', 1),
#  ('Chlorphenon', 1),
#  ('Chlorphenoxamine', 1),
#  ('Chlorpromazine', 1),
#  ('Chlorpropamide', 1),
#  ('Chlortalidone', 1),
#  ('Chlorzoxazone', 1),
#  ('Cholecaps', 1),
#  ('Cholespar', 1),
#  ('Cholestat', 1),
#  ('Cholexin', 1),
#  ('Cholimed', 1),
#  ('Cholinaar', 1),
#  ('Choline Salicylate', 1),
#  ('Cholvastin', 1),
#  ('Chopintac Chopintac/Chop', 1),
#  ('Choriogonadotropin Alfa', 1),
#  ('Chromagen', 1),
#  ('Chromalux', 1),
#  ('Chromazol', 1),
#  ('Chromium Picolinate', 1),
#  ('Chymotrypsin', 1),
#  ('Cialis', 1),
#  ('Cibren', 1),
#  ('Ciclesonide', 1),
#  ('Cicletanine', 1),
#  ('Ciclopirox', 1),
#  ('Ciclosporin', 1),
#  ('Ciflos', 1),
#  ('Cifloxan', 1),
#  ('Cilazapril', 1),
#  ('Cilnidipine', 1),
#  ('Cilostazol', 1),
#  ('Cimetidine', 1),
#  ('Cimetidine Indo Farma', 1),
#  ('Cimetropium Bromide', 1),
#  ('Cimexol', 1),
#  ('Cinacalcet', 1),
#  ('Cinchocaine', 1),
#  ('Cinchona Calisaya', 1),
#  ('Cindala', 1),
#  ('Cindala Gel', 1),
#  ('Cinnarizine', 1),
#  ('Cinoxacin', 1),
#  ('Ciprazol', 1),
#  ('Ciprec 500', 1),
#  ('Ciprobiotic', 1),
#  ('Ciprofibrate', 1),
#  ('Ciprofloxacin', 1),
#  ('Ciprofloxacin Eye Drops Indo Farma', 1),
#  ('Ciprofloxacin Fresenius', 1),
#  ('Ciprofloxacin Hexpharm J', 1),
#  ('Ciprofloxacin Hexpharm Jaya', 1),
#  ('Ciprofloxacin Ikapharmindo', 1),
#  ('Ciprofloxacin Indo Farma', 1),
#  ('Ciprofloxacin OGB Dexa', 1),
#  ('Ciprofloxacin Phapros', 1),
#  ('Ciprofloxacin Soho', 1),
#  ('Ciprolex', 1),
#  ('Ciproxin Ciproxin/Ciprox', 1),
#  ('Ciri-ciri Orang yang Sakau Narkoba Heroin', 1),
#  ('Cirrus', 1),
#  ('Cisapride', 1),
#  ('Cisplatin', 1),
#  ('Citalopram', 1),
#  ('Citaz', 1),
#  ('Citicholine', 1),
#  ('Citicoline', 1),
#  ('Citicoline MPL', 1),
#  ('Citicoline OGB Dexa Medica', 1),
#  ('Citicoline OGB Mersi', 1),
#  ('Citric Acid + Sodium Bicarbonate + Simethicone', 1),
#  ('Citrosol', 1),
#  ('Civell', 1),
#  ('Clacef', 1),
#  ('Clacine', 1),
#  ('Cladribine', 1),
#  ('Clafexim', 1),
#  ('Claforan', 1),
#  ('Clambiotic', 1),
#  ('Clamoxyl', 1),
#  ('Clarihis', 1),
#  ('Clarithromycin', 1),
#  ('Claritin', 1),
#  ('Classic', 1),
#  ('Clast', 1),
#  ('Clatatin', 1),
#  ('Clatax', 1),
#  ('Clebopride', 1),
#  ('Clemastine', 1),
#  ('Clenbuterol', 1),
#  ('Cliad', 1),
#  ('Clidacor', 1),
#  ('Clidacor Gel', 1),
#  ('Clidiaz', 1),
#  ('Clidorel', 1),
#  ('Climadan', 1),
#  ('Clinbercin', 1),
#  ('Clindamycin', 1),
#  ('Clindamycin dan Benzoyl Peroxide', 1),
#  ('Clindamycin Indo Farma', 1),
#  ('Clindamycin OGB Dexa', 1),
#  ('Clindexcin', 1),
#  ('Clinex', 1),
#  ('Clinidac', 1),
#  ('Clinika', 1),
#  ('Clinika Gel', 1),
#  ('Clinium', 1),
#  ('Clinium Gel', 1),
#  ('Clinjos', 1),
#  ('Clinmas', 1),
#  ('Clioquinol', 1),
#  ('Clobazam', 1),
#  ('Clobazam OGB Dexa', 1),
#  ('Clobesan', 1),
#  ('Clobetasol', 1),
#  ('Clobetasone', 1),
#  ('Clobium', 1),
#  ('Clofalam', 1),
#  ('Clofazimine', 1),
#  ('Clofedanol', 1),
#  ('Clofibrate', 1),
#  ('Cloflam', 1),
#  ('Clofritis', 1),
#  ('Clogin', 1),
#  ('Clomethiazole', 1),
#  ('Clomifene', 1),
#  ('Clomipramine', 1),
#  ('Clonaderm', 1),
#  ('Clonate', 1),
#  ('Clonazepam', 1),
#  ('Clonex', 1),
#  ('Clonidine', 1),
#  ('Clonidine Indo Farma', 1),
#  ('Clopamide', 1),
#  ('Clopidogrel', 1),
#  ('Clopidogrel Fahrenheit', 1),
#  ('Clopidogrel Hexpharm', 1),
#  ('Clopidogrel Ikapharmindo', 1),
#  ('Clopidogrel Kalbe', 1),
#  ('Clopidogrel Soho', 1),
#  ('Clopine', 1),
#  ('Clopisan', 1),
#  ('Clopramel', 1),
#  ('Cloracef', 1),
#  ('Cloramidina', 1),
#  ('Cloramidina Salep Mata C', 1),
#  ('Cloramidina Salep Topika', 1),
#  ('Clorazepate', 1),
#  ('Clorilex', 1),
#  ('Clotiapine', 1),
#  ('Clotix', 1),
#  ('Clotrimazole', 1),
#  ('Clovertil', 1),
#  ('Cloxacillin', 1),
#  ('Clozapine', 1),
#  ('Clozapine OGB Mersi', 1),
#  ('Clozaril', 1),
#  ('Co-Trimoxazole', 1),
#  ('Co-Trimoxazole Indo Farma', 1),
#  ('Coal Tar', 1),
#  ('Cocefin', 1),
#  ('Codeine', 1),
#  ('Codikaf', 1),
#  ('Cofact', 1),
#  ('Cohistan', 1),
#  ('Colchicine', 1),
#  ('Colesevelam', 1),
#  ('Colestipol', 1),
#  ('Colfosceril Palmitate', 1),
#  ('Colidium', 1),
#  ('Colinpha', 1),
#  ('Colme', 1),
#  ('Colme Eye Colme Eye Drop', 1),
#  ('Colsancetine', 1),
#  ('Combantrin', 1),
#  ('Combicef', 1),
#  ('Combicetin', 1),
#  ('Combicitrine', 1),
#  ('Combivent', 1),
#  ('Comdasin', 1),
#  ('Comdasin Larutan Comdasi', 1),
#  ('Comedrol', 1),
#  ('Compraz', 1),
#  ('Comsporin', 1),
#  ('Comtan', 1),
#  ('Comtro', 1),
#  ('Concerta', 1),
#  ('Concor', 1),
#  ('Condiabet', 1),
#  ('Conmycin', 1),
#  ('Conpidone', 1),
#  ('Conprazole', 1),
#  ('Conranin', 1),
#  ('Constantia', 1),
#  ('Contral', 1),
#  ('Contram 50', 1),
#  ('Contratemp Contratemp/Co', 1),
#  ('Copidrel', 1),
#  ('Coralan', 1),
#  ('Cordalat', 1),
#  ('Cordila SR', 1),
#  ('Cordizem', 1),
#  ('Corifam', 1),
#  ('Coritrope', 1),
#  ('Corocyd', 1),
#  ('Coroflox', 1),
#  ('Coronipin', 1),
#  ('Corpamil', 1),
#  ('Corsabutol', 1),
#  ('Corsacin', 1),
#  ('Corsadol', 1),
#  ('Corsagyl', 1),
#  ('Corsamet', 1),
#  ('Corsamycin', 1),
#  ('Corsasep', 1),
#  ('Corsatet 250', 1),
#  ('Corsatrocin', 1),
#  ('Corsazinamid', 1),
#  ('Corstanal', 1),
#  ('Corticorelin', 1),
#  ('Cortidex', 1),
#  ('Cortigra', 1),
#  ('Cortisone', 1),
#  ('Cortisone Acetate Ikapharmindo', 1),
#  ('Cortisone Harsen', 1),
#  ('Corvox', 1),
#  ('Cosmofer', 1),
#  ('Costil', 1),
#  ('Counterpain', 1),
#  ('Counterpain/Counterpain Cool', 1),
#  ('Courage', 1),
#  ('Coversyl', 1),
#  ('Cozaar', 1),
#  ('CPG', 1),
#  ('Cravit Lar Mata Cravit O', 1),
#  ('Cravit/Cravit IV', 1),
#  ('Cravox/Cravox IV', 1),
#  ('Crestor', 1),
#  ('Criax', 1),
#  ('Crinone', 1),
#  ('Crolin', 1),
#  ('Crome', 1),
#  ('Cronitin', 1),
#  ('Crotamiton', 1),
#  ('Cryptal', 1),
#  ('CSB', 1),
#  ('CTM Berlico', 1),
#  ('Cupanol', 1),
#  ('Curcuma FCT Tablet', 1),
#  ('Curcuma Plus', 1),
#  ('Cyamemazine', 1),
#  ('Cyanamin TRC', 1),
#  ('Cyanocobalamin', 1),
#  ('Cybutol', 1),
#  ('Cyclandelate', 1),
#  ('Cyclizine', 1),
#  ('Cyclobenzaprine', 1),
#  ('Cyclopenthiazide', 1),
#  ('Cyclopentolate', 1),
#  ('Cyclopentolate dan Phenylephrine', 1),
#  ('Cyclophosphamide', 1),
#  ('Cyclophosphamide Kalbe', 1),
#  ('Cycloserine', 1),
#  ('Cyclosporine', 1),
#  ('Cyclovid', 1),
#  ('Cycortide', 1),
#  ('Cygest', 1),
#  ('Cylat', 1),
#  ('Cymevene', 1),
#  ('Cyproheptadine', 1),
#  ('Cyproplex Combiphar/Pharmachemie', 1),
#  ('Cyproterone', 1),
#  ('Cytarabine', 1),
#  ('Cytarabine DBL', 1),
#  ('Cytistat', 1),
#  ('Cytosafe Carboplatin', 1),
#  ('Cytosar-U', 1),
#  ('Cytostol', 1),
#  ('Cytotec', 1),
#  ('Dabigatran', 1),
#  ('Dacarbazine DBL', 1),
#  ('Dacarbazine Medac', 1),
#  ('Dacin', 1),
#  ('Daclin Acne', 1),
#  ('Daclin-300', 1),
#  ('Dactinomycin', 1),
#  ('Daivonex', 1),
#  ('Daktarin Oral Gel', 1),
#  ('Daktazol', 1),
#  ('Dalacin C', 1),
#  ('Dalfarol', 1),
#  ('Dalmadorm', 1),
#  ('Damaben', 1),
#  ('Dampak Mencampur Alkohol Dengan Obat', 1),
#  ('Danazol', 1),
#  ('Danocrine', 1),
#  ('Dantrolene', 1),
#  ('Dantroxal', 1),
#  ('Daonil', 1),
#  ('Dapagliflozin', 1),
#  ('Dapsone', 1),
#  ('Daptomycin', 1),
#  ('Darbepoetin Alfa', 1),
#  ('Darifenacin', 1),
#  ('Daryacef', 1),
#  ('Daryaven', 1),
#  ('DaryaZinc', 1),
#  ('Dasatinib', 1),
#  ('Datan/Datan Forte', 1),
#  ('Daunocin', 1),
#  ('Daunorubicin', 1),
#  ('Daunorubicin HCl DBL', 1),
#  ...]

# %% [markdown]
# ### Nomor 7

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get('https://resepkoki.id/resep/resep-rendang-daging-sapi-padang/')
soup = BeautifulSoup(page.content, 'lxml')
arr_resep = soup.findAll('table', {'span': 'ingredient-name'})
arr_resep_str = []
for o in arr_resep:
    arr_resep_str.append(o.find('span').text)

# %%
from collections import Counter

Counter(arr_resep_str).most_common()
# Out:
# []

# %% [markdown]
# # Tugas
#
# 1. Ubah <b>Code 5</b> dan simpan hasil <i>crawling</i> menggunakan <i>code</i> tersebut dengan nama `hasil_tweet_c5.csv`. Hasil <i>crawling</i> yang disimpan berupa:
#     * Jika Anda laki-laki dan angka-angka NPM Anda ditotalkan menjadi bilangan genap: teks <i>tweet</i> dan <i>bio author</i>
#     * Jika Anda laki-laki dan angka-angka NPM Anda ditotalkan menjadi bilangan ganjil: teks <i>tweet</i> dan jumlah <i>follower author</i>
#     * Jika Anda perempuan dan angka-angka NPM Anda ditotalkan menjadi bilangan genap: teks <i>tweet</i> dan jumlah <i>favorite tweet</i> tersebut
#     * Jika Anda perempuan dan angka-angka NPM Anda ditotalkan menjadi bilangan ganjil: teks <i>tweet</i> dan jumlah <i>retweet tweet</i> tersebut
#
# 2. Ubah <b>Code 9</b> dan simpan 10 <i>tweet</i> berbahasa Indonesia hasil <i>crawling</i> menggunakan <i>code</i> tersebut dengan nama `hasil_tweet_c9.csv`. Hasil <i>crawling</i> yang disimpan berupa:
#     * Jika angka kedua terakhir NPM Anda genap dan angkatan 2018: teks <i>tweet</i> dan warna <i>background</i> profil <i>author</i>
#     * Jika angka kedua terakhir NPM Anda genap dan bukan angkatan 2018: teks <i>tweet</i> dan warna teks profil <i>author</i>
#     * Jika angka kedua terakhir NPM Anda ganjil dan angkatan 2018: teks <i>tweet</i> dan informasi waktu <i>tweet</i> dibuat
#     * Jika angka kedua terakhir NPM Anda genap dan bukan angkatan 2018: teks <i>tweet</i> dan <i>id tweet</i>
#
# 3. Dengan menggunakan Twitter Search, carilah 10 <i>tweet</i> populer dengan kata kunci
# sesuai pembagian berikut:
# <table>
# <tr><th>Angka terakhir pada NPM</th><th>Kata kunci</th></tr>
# <tr><td>0, 1, 2, 3</td><td>psbb OR ppkm</td></tr>
# <tr><td>4, 5, 6</td><td>‘virus corona’</td></tr>
# </table>
# Simpan <i>tweet</i> tersebut dengan nama `hasil_tweet_populer1.csv`
#
# 4. Dengan menggunakan Twitter Search, carilah 10 <i>tweet</i> populer dengan kata kunci
# sesuai pembagian berikut:
# <table>
# <tr><th>Angka terakhir pada NPM</th><th>Kata kunci</th></tr>
# <tr><td>0, 1, 2, 3</td><td>psbb -ppkm</td></tr>
# <tr><td>4, 5, 6</td><td>‘virus OR corona’</td></tr>
# </table>
# Simpan <i>tweet</i> tersebut dengan nama `hasil_tweet_populer2.csv`
#
# 5. Adakah perbedaan antara hasil no 3 dan no 4? Jika ada, apakah yang membedakan kedua hasil tersebut?
#
# 6. Lakukan modifikasi pada <b>Code 10</b> agar <i>code</i> dapat mengekstrak informasi <i>slug post</i> sebuah diskusi. Contoh <i>output</i> yang diharapkan:
# <table>
# <tr><th>judul</th><th>pemberi_balasan</th><th>penanya</th><th>slug</th></tr>
# <tr><td>Mata kembali bengkak dan kemerahan di daerah bekas operasi kalazion</td><td>dr.Tabita Padmaya Setiawan</td><td>Yumi</td><td>/komunitas/topic/kelopak-mata-bengkak551b6e</td></tr>
# <tr><td>...</td><td>...</td><td>...</td><td>...</td></tr>
# </table>
#
# 7. Dengan menggunakan <i>library> requests</i>, <i>BeautifulSoup</i>, dan <i>json</i>, <i>crawling</i> bahan-bahan untuk membuat:
#     * <a href="https://resepkoki.id/resep/resep-rendang-daging-sapi-padang/">Rendang daging sapi padang</a> jika jumlah huruf konsonan nama Anda genap
#     * <a href="https://resepkoki.id/resep/resep-bubur-ayam-quaker-oat/">Bubur Ayam Quaker Oat</a> jika jumlah huruf konsonan nama Anda ganjil
# <br><br>Contoh <i>output</i> yang diharapkan dari resep <a href="https://resepkoki.id/resep/resep-es-alpukat/">Es Alpukat</a>):
# ```
# ['Alpukat matang: 2 buah',
#  'Susu evaporasi (1 kaleng): 380 gram',
#  'Nata de coco, dan airnya: 250 gram',
#  'Susu kental manis putih: 60 ml',
#  'Selasih: 1 sdm',
#  'Pasta pandan: 5 tetes',
#  'Es batu: secukupnya']
# ```
#
# 8. [BONUS] Lakukan <i>scraping</i> profil Linkedin beberapa perusahaan e-Commerce terbesar di Indonesia sesuai dengan pembagian berikut:
# <table>
# <tr><th>Awalan huruf nama lengkap</th><th>URL Linkedin Perusahaan</th></tr>
# <tr><td>A-E</td><td>https://www.linkedin.com/company/pt--tokopedia/</td></tr>
# <tr><td>F-Q</td><td>https://www.linkedin.com/company/shopee/</td></tr>
# <tr><td>R-Z</td><td>https://www.linkedin.com/company/pt-bukalapak-com/</td></tr>
# </table>
# <i>Note:</i> Anda dapat menggunakan <i>code</i> <a href="https://github.com/joeyism/linkedin_scraper/blob/master/linkedin_scraper/company.py">ini</a> sebagai referensi atau membuat <i>scraper</i> sendiri dari awal. Informasi yang perlu diambil adalah nama, <i>bio</i>, dan deskripsi singkat tentang perusahaan. Berikut merupakan contoh hasil <i>scraping</i> dari profil Linkedin Blibli.com:
#
# ```
# {
#     "nama": "Blibli.com",
#     "bio": "Young generation who demonstrate R.E.S.P.E.C.T and dare to deliver impactful action for the nation!"
#     "deskripsi": "Blibli.com is an e-commerce platform built upon a big dream: to lead Indonesians to enter a new digital lifestyle and give only the best shopping experience for a better life. We are committed to conduct our business with customer-centric minded, striving to deliver the best features and services to satisfy our customers. We aim for an exciting challenge to become the number 1 e-commerce platform in Indonesia by providing the best customer-centric experience for both buyers and sellers. Blibli.com is created by Indonesians, in Indonesia, and for Indonesians; we’re here as an inspiration to channel and empower the Indonesian people to engage and socialize in commercial activities.\n\nWe understand this is a big challenge to be accomplished in one night. Yet, it’s a challenge we are ready to take. We realize a big dream like ours requires a big and stronger team. So, for our first step, we gather a group of talented and passionate people as our main power, and we spend a lot of quality time and effort to make our big dream come true.\n\nOur team consists of people who dare to dream and act big to reach their goals. We are the people who always go the extra miles only to provide the best service available passionately and proudly. We work together and become stronger by bringing in the best shopping experience for our customers.\n\nWe believe how we act within team will mirror the service that our customers receive. To achieve it, we believe in R.E.S.P.E.C.T. as the foundation of our daily action. By instilling R.E.S.P.E.C.T., we understand and build trust among the team and the customers. We actively fertilize our seed of big dream with their precious trust to Blibli.com. This then develops us to grow as a better company with the ever growing value, service, and product.\n\nThis is how we aim to deliver BIG CHOICES BIG DEALS for all. And in the end, just like a big and strong team we’re growing into, we could bring the best shopping experience for a better life!"
# }
# ```
#
# <i>Deadline</i> pengumpulan Tugas adalah Senin, 8 Maret 2021 pukul 08:00 di SCeLE. Berkas yang dikumpulkan adalah Tutorial 1 - Data Collection.ipynb dan seluruh berkas csv. Kumpulkan semua berkas dalam zip dengan format penamaan Tutorial1_Nama_NPM.zip.
